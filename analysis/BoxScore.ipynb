# %%
from plyball.mlb import MLBStats
import datetime as dt

# %%
MLBStats().get_game_boxscore(game_pk=746479, run_date=dt.datetime(2024,6, 9,14,37,8))
# Out:
# person=Person(id=656716, fullName='Zach McKinstry', link='/api/v1/people/656716') jerseyNumber='39' position=PlayerPosition(code='6', name='Shortstop', type='Infielder', abbreviation='SS') status=PlayerStatus(code='A', description='Active') parentTeamId=116 battingOrder=None stats=PlayerGameStats(batting={}, pitching={}, fielding={}) seasonStats=PlayerSeasonStats(batting={'gamesPlayed': 26, 'flyOuts': 8, 'groundOuts': 12, 'airOuts': 13, 'runs': 3, 'doubles': 1, 'triples': 1, 'homeRuns': 0, 'strikeOuts': 19, 'baseOnBalls': 5, 'intentionalWalks': 0, 'hits': 13, 'hitByPitch': 1, 'avg': '.232', 'atBats': 56, 'obp': '.302', 'slg': '.286', 'ops': '.588', 'caughtStealing': 0, 'stolenBases': 1, 'stolenBasePercentage': '1.000', 'groundIntoDoublePlay': 0, 'groundIntoTriplePlay': 0, 'plateAppearances': 63, 'totalBases': 16, 'rbi': 3, 'leftOnBase': 16, 'sacBunts': 0, 'sacFlies': 1, 'babip': '.342', 'groundOutsToAirouts': '0.92', 'catchersInterference': 0, 'pickoffs': 0, 'atBatsPerHomeRun': '-.--
# ...
